# %% [markdown]
# # LLaMA Training on Google Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR_USERNAME/llm-from-scratch/blob/main/notebooks/train_llama_colab.ipynb)
#
# ## Setup
#
# 1. Runtime > Change runtime type > GPU (T4)
# 2. Run all cells

# %%
# Clone repository
# !git clone https://github.com/YOUR_USERNAME/llm-from-scratch.git
# %cd llm-from-scratch

# %%
# Install dependencies
# !pip install -q torch torchinfo pytorch-lightning wandb datasets regex tokenizers

# %%
# Check GPU
import torch

print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f}GB")

# %% [markdown]
# ## Prepare Tokenizer

# %%
# !python -m scripts.prepare_local --model-type=llama --num-samples=50000

# %% [markdown]
# ## Train Model

# %%
# !python -m scripts.train_local --model-type=llama --run-name=llama-colab

# %% [markdown]
# ## Test Inference

# %%
# !python -m scripts.inference --run-name=llama-colab --model-type=llama --mode=local

# %% [markdown]
# ## Download Model

# %%
# Create archive
# !tar -czf llama_model.tar.gz checkpoints/ tokenizers/

# Download to local machine
from google.colab import files

files.download("llama_model.tar.gz")
